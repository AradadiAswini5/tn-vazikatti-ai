# %% [markdown]
# <span style="color: red; font-size: 20px;">Install Required Packages</span>

# %%
# !pip install faiss-cpu
# !pip install sentence-transformers
# !pip install transformers accelerate sentencepiece
# !pip install gradio
# !pip install numpy
# Out:
# Requirement already satisfied: faiss-cpu in c:\anaconda\envs\aiml\lib\site-packages (1.13.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\anaconda\envs\aiml\lib\site-packages (from faiss-cpu) (2.0.0)
# Requirement already satisfied: packaging in c:\anaconda\envs\aiml\lib\site-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: sentence-transformers in c:\anaconda\envs\aiml\lib\site-packages (5.1.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (1.5.0)
# Requirement already satisfied: scipy in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\anaconda\envs\aiml\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: networkx in c:\anaconda\envs\aiml\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\anaconda\envs\aiml\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\anaconda\envs\aiml\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\anaconda\envs\aiml\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda\envs\aiml\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\anaconda\envs\aiml\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\envs\aiml\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\anaconda\envs\aiml\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\anaconda\envs\aiml\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: transformers in c:\anaconda\envs\aiml\lib\site-packages (4.57.1)
# Collecting accelerate
#   Using cached accelerate-1.11.0-py3-none-any.whl.metadata (19 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.1-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: filelock in c:\anaconda\envs\aiml\lib\site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\anaconda\envs\aiml\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\anaconda\envs\aiml\lib\site-packages (from transformers) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\envs\aiml\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\anaconda\envs\aiml\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\anaconda\envs\aiml\lib\site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\anaconda\envs\aiml\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\anaconda\envs\aiml\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\anaconda\envs\aiml\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\anaconda\envs\aiml\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\anaconda\envs\aiml\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\anaconda\envs\aiml\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: psutil in c:\anaconda\envs\aiml\lib\site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: torch>=2.0.0 in c:\anaconda\envs\aiml\lib\site-packages (from accelerate) (2.5.1)
# Requirement already satisfied: networkx in c:\anaconda\envs\aiml\lib\site-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in c:\anaconda\envs\aiml\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: setuptools in c:\anaconda\envs\aiml\lib\site-packages (from torch>=2.0.0->accelerate) (80.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\anaconda\envs\aiml\lib\site-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda\envs\aiml\lib\site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in c:\anaconda\envs\aiml\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\envs\aiml\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers) (2025.10.5)
# Using cached accelerate-1.11.0-py3-none-any.whl (375 kB)
# Downloading sentencepiece-0.2.1-cp312-cp312-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 6.3 MB/s  0:00:00
# Installing collected packages: sentencepiece, accelerate
#
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    -------------------- ------------------- 1/2 [accelerate]
#    ---------------------------------------- 2/2 [accelerate]
#
# Successfully installed accelerate-1.11.0 sentencepiece-0.2.1
# Requirement already satisfied: gradio in c:\anaconda\envs\aiml\lib\site-packages (5.49.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (4.10.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.121.2)
# Requirement already satisfied: ffmpy in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==1.13.3 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (2.0.0)
# Requirement already satisfied: orjson~=3.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (3.11.3)
# Requirement already satisfied: packaging in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (2.11.10)
# Requirement already satisfied: pydub in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.14.5)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.49.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio) (0.38.0)
# Requirement already satisfied: fsspec in c:\anaconda\envs\aiml\lib\site-packages (from gradio-client==1.13.3->gradio) (2025.10.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in c:\anaconda\envs\aiml\lib\site-packages (from gradio-client==1.13.3->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\anaconda\envs\aiml\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\anaconda\envs\aiml\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\anaconda\envs\aiml\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in c:\anaconda\envs\aiml\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\anaconda\envs\aiml\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\anaconda\envs\aiml\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\anaconda\envs\aiml\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.0)
# Requirement already satisfied: requests in c:\anaconda\envs\aiml\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\anaconda\envs\aiml\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda\envs\aiml\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\envs\aiml\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda\envs\aiml\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\anaconda\envs\aiml\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\anaconda\envs\aiml\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\anaconda\envs\aiml\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in c:\anaconda\envs\aiml\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\anaconda\envs\aiml\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\anaconda\envs\aiml\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.2.0)
# Requirement already satisfied: colorama in c:\anaconda\envs\aiml\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\anaconda\envs\aiml\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\anaconda\envs\aiml\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\anaconda\envs\aiml\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda\envs\aiml\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda\envs\aiml\lib\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\envs\aiml\lib\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (1.26.18)
# Requirement already satisfied: numpy in c:\anaconda\envs\aiml\lib\site-packages (2.0.0)

# %% [markdown]
# <span style="color: red; font-size: 20px;">Setup Groq Client</span>

# %%
import os
from openai import OpenAI

# Set your Groq API key
os.environ["GROQ_API_KEY"] = "GROQ_API_KEY"

# Initialize Groq client
client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

print("PHASE 1 DONE — Groq Client Connected Successfully!")
# Out:
# PHASE 1 DONE — Groq Client Connected Successfully!

# %% [markdown]
# <span style="color: red; font-size: 20px;">PHASE 2 — Create sample TN Gov Dataset</span>

# %%
# ================================
# PHASE 2 — Create Dataset Folder & Sample TN Govt Data
# ================================

from pathlib import Path

DATA_DIR = Path("tn_docs")
DATA_DIR.mkdir(exist_ok=True)

sample_text = """
WIDOW PENSION:
Eligibility:
- Applicant must be a widow living in Tamil Nadu.
- Annual income must be below government limit.

How to Apply:
- Visit your Taluk Office.
- Submit Husband's Death Certificate, Aadhaar, Address Proof.
- Application reviewed by VAO and RI.
- Pension amount credited monthly.

COMMUNITY CERTIFICATE:
Process:
- Apply via e-Sevai Centre or Taluk Office.
- Submit Aadhaar, Address Proof, School TC.
- Fee: Rs. 60
- Certificates issued by Revenue Department.

DRIVING LICENSE RENEWAL:
Procedure:
- Apply via Parivahan Website or RTO.
- Required: Existing DL, Aadhaar, Address Proof.
- Pay renewal fee online.
- Collect renewed DL from RTO.

OLD AGE PENSION:
Eligibility:
- Age 60+
- No family support
- Must be a resident of Tamil Nadu
- Monthly pension amount: Rs. 1,000

DISABILITY CERTIFICATE:
Steps:
- Visit District HQ Hospital.
- Meet Medical Board.
- Submit medical records, Aadhaar, photos.

VOTER ID APPLICATION (FORM-6):

Eligibility:
- Must be 18+ years old.
- Must be a resident of the constituency.
- Must not be registered as a voter in any other location.

How to Apply:
1. Visit https://voters.eci.gov.in or use the Voter Helpline App.
2. Select "Form 6 – New Voter Registration".
3. Fill personal details: Name, DOB, Gender.
4. Upload documents:
   - Address proof (Aadhaar / Ration Card / Passport / Electricity Bill)
   - Age proof (Birth Certificate / SSLC Certificate)
5. Add family voter details (optional).
6. Submit application.

Offline Method:
1. Visit your nearest BLO (Booth Level Officer) / Taluk office.
2. Fill Form-6 manually.
3. Attach photocopies of address and age proof.
4. Submit to BLO.

Verification:
- BLO will visit your home or verify documents.
- After approval, Voter ID will be generated.

Download:
- Visit https://voters.eci.gov.in
- Select “Download e-EPIC”
"""

# Save sample data
(DATA_DIR / "tn_sample.txt").write_text(sample_text, encoding="utf-8")

print("PHASE 2 DONE — tn_docs folder created & sample data saved")
# Out:
# PHASE 2 DONE — tn_docs folder created & sample data saved

# %% [markdown]
# <span style="color: red; font-size: 20px;">PHASE 3 — Text Chunking for RAG</span>

# %%
def chunk_text(text, max_words=120):
    """
    Splits long text into smaller chunks.
    max_words=120 means each chunk has ~120 words.
    """
    words = text.split()
    chunks = []

    for i in range(0, len(words), max_words):
        chunk = " ".join(words[i:i + max_words])
        chunks.append(chunk)

    return chunks


# Load all text files from tn_docs/
docs = []
sources = []

for file in DATA_DIR.glob("*.txt"):
    content = file.read_text(encoding="utf-8")
    chunks = chunk_text(content)

    docs.extend(chunks)
    sources.extend([file.name] * len(chunks))

print("PHASE 3 DONE — Chunking complete!")
print("Total Chunks Created:", len(docs))
print("Example Chunk:\n", docs[0][:300], "...")
# Out:
# PHASE 3 DONE — Chunking complete!
# Total Chunks Created: 3
# Example Chunk:
#  WIDOW PENSION: Eligibility: - Applicant must be a widow living in Tamil Nadu. - Annual income must be below government limit. How to Apply: - Visit your Taluk Office. - Submit Husband's Death Certificate, Aadhaar, Address Proof. - Application reviewed by VAO and RI. - Pension amount credited monthly ...

# %% [markdown]
# <span style="color: red; font-size: 20px;">PHASE 4 — Embeddings (text-embedding-3-small)</span>

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\anaconda\envs\aiml\lib\site-packages (5.1.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (1.5.0)
# Requirement already satisfied: scipy in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\anaconda\envs\aiml\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\anaconda\envs\aiml\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\anaconda\envs\aiml\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: networkx in c:\anaconda\envs\aiml\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\anaconda\envs\aiml\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\anaconda\envs\aiml\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\anaconda\envs\aiml\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda\envs\aiml\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\anaconda\envs\aiml\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\envs\aiml\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\envs\aiml\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\anaconda\envs\aiml\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\anaconda\envs\aiml\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# Best free Tamil + English embedding model
embed_model = SentenceTransformer("intfloat/multilingual-e5-small")

def embed_text(text_list):
    """
    Generate embeddings using multilingual-e5-small (local CPU).
    """
    vectors = embed_model.encode(text_list, convert_to_numpy=True, normalize_embeddings=True)
    return vectors.astype("float32")

# Generate embeddings for all chunks
embeddings = embed_text(docs)

print("PHASE 4 DONE — HuggingFace Embeddings Created.")
print("Embedding shape:", embeddings.shape)
# Out:
# PHASE 4 DONE — HuggingFace Embeddings Created.
# Embedding shape: (3, 384)

# %%
print(embed_text(["widow pension tamil nadu"]).shape)
# Out:
# (1, 384)

# %% [markdown]
# <span style="color: red; font-size: 20px;">PHASE 5 — Build FAISS Index</span>

# %%
import faiss
import json

# Create FAISS index
index = faiss.IndexFlatL2(embeddings.shape[1])
index.add(embeddings)

# Save index + metadata
faiss.write_index(index, "tn_faiss.index")

metadata = {
    "docs": docs,
    "sources": sources
}
json.dump(metadata, open("tn_meta.json", "w"))

print("PHASE 5 DONE — FAISS Index Created & Saved.")
# Out:
# PHASE 5 DONE — FAISS Index Created & Saved.

# %% [markdown]
# <span style="color: red; font-size: 20px;">PHASE 6 — Retrieval Function</span>

# %%
def retrieve(query, k=3):
    """
    Finds top-k similar chunks using FAISS.
    """
    index = faiss.read_index("tn_faiss.index")
    meta = json.load(open("tn_meta.json"))

    q_emb = embed_text([query])
    distances, idxs = index.search(q_emb, k)

    results = []
    for i in idxs[0]:
        results.append({
            "text": meta["docs"][i],
            "source": meta["sources"][i]
        })
    
    return results

# Quick test
print("PHASE 6 DONE — Retrieval test:", retrieve("widow pension")[0])
# Out:
# PHASE 6 DONE — Retrieval test: {'text': "WIDOW PENSION: Eligibility: - Applicant must be a widow living in Tamil Nadu. - Annual income must be below government limit. How to Apply: - Visit your Taluk Office. - Submit Husband's Death Certificate, Aadhaar, Address Proof. - Application reviewed by VAO and RI. - Pension amount credited monthly. COMMUNITY CERTIFICATE: Process: - Apply via e-Sevai Centre or Taluk Office. - Submit Aadhaar, Address Proof, School TC. - Fee: Rs. 60 - Certificates issued by Revenue Department. DRIVING LICENSE RENEWAL: Procedure: - Apply via Parivahan Website or RTO. - Required: Existing DL, Aadhaar, Address Proof. - Pay renewal fee online. - Collect renewed DL from RTO. OLD AGE PENSION: Eligibility: - Age 60+ - No family support - Must be", 'source': 'tn_sample.txt'}

# %% [markdown]
# <span style="color: red; font-size: 20px;">PHASE 7 — Prompt Builder (English + Tamil)</span>

# %%
def build_prompt(query):
    ctx_chunks = retrieve(query)
    context_text = "\n\n".join([c["text"] for c in ctx_chunks])

    prompt = f"""
You are a Tamil Nadu Government Assistant.

Context:
{context_text}

User Question:
{query}

Instructions:
1. First answer in clear ENGLISH based ONLY on the context.
2. Then give the SAME answer in clear TAMIL.
3. If context does NOT contain the answer:
   English: "Information not available."
   Tamil: "தகவல் கிடைக்கவில்லை."

Answer:
"""
    return prompt

print("PHASE 7 DONE — Prompt builder ready.")
# Out:
# PHASE 7 DONE — Prompt builder ready.

# %% [markdown]
# <span style="color: red; font-size: 20px;">PHASE 8 — Answer Generator (gpt-oss-120b)</span>

# %%
def is_small_talk(text):
    text = text.lower().strip()
    greetings = ["hi", "hello", "hey", "vanakkam", "good morning", "good evening", "good afternoon"]
    return text in greetings or len(text.split()) <= 2

def tn_answer(query):
    # ---- 1. Handle greetings / small talk (NO RAG) ----
    if is_small_talk(query):
        response = client.chat.completions.create(
            model="openai/gpt-oss-120b",
            messages=[
                {"role": "system", "content": "You are a friendly Tamil Nadu Government Assistant."},
                {"role": "user", "content": f"Respond politely in English and Tamil to: {query}"}
            ]
        )
        return response.choices[0].message.content
    
    # ---- 2. Normal RAG processing ----
    prompt = build_prompt(query)

    response = client.chat.completions.create(
        model="openai/gpt-oss-120b",
        messages=[
            {"role": "system", "content": "You are a helpful Tamil Nadu Government Assistant."},
            {"role": "user", "content": prompt}
        ]
    )

    return response.choices[0].message.content

# %%
# Test

print(tn_answer("How to apply for widow pension in Tamil Nadu?"))
# Out:
# **Answer in English**
#
# **How to apply for Widow Pension in Tamil Nadu**
#
# 1. **Check eligibility** – You must be a widow residing in Tamil Nadu and your annual family income must be below the government‑specified limit.
# 2. **Visit your Taluk Office** – Go to the Taluk Office that serves your area.
# 3. **Submit the required documents**
#    - Husband’s Death Certificate
#    - Your Aadhaar card (identity & address)
#    - Proof of your current address (e.g., electricity bill, rent agreement, etc.)
# 4. **Application processing** – The application will be examined by the Village Administrative Officer (VAO) and the Revenue Inspector (RI).
# 5. **Pension credit** – Once approved, the widow pension amount will be credited to your bank account on a monthly basis.
#
# ---
#
# **தமிழில் பதில்**
#
# **தமிழ்நாட்டில் விதவை பेंஷனை பெற விண்ணப்பிக்கும் முறை**
#
# 1. **தகுதி உறுதி** – நீங்கள் தமிழ்நாட்டில் வசிக்கும் விதவை ஆவீர்கள், மேலும் உங்கள் வருடாந்திர குடும்ப வருமானம் அரசு நிர்ணயித்த வரம்புக்கு கீழ் இருக்க வேண்டும்.
# 2. **உங்கள் தாலுக் அலுவலகத்திற்கு செல்லவும்** – உங்கள் இடத்திற்கு சேர்ந்த தாலுக் அலுவலகத்திற்கு சென்று விண்ணப்பிக்கவும்.
# 3. **தேவையான ஆவணங்களை சமர்ப்பிக்கவும்**
#    - கணவர் இறப்பு சான்றிதழ்
#    - உங்கள் ஆதார் அட்டை (அடையாளம் & முகவரி)
#    - தற்போதைய முகவரி சான்று (மின்சாரம் பில், வாடகை ஒப்பந்தம் போன்றவை)
# 4. **விண்ணப்பம் பரிசீலனை** – உங்கள் விண்ணப்பம் கிராம நிர்வாக அதிகாரி (VAO) மற்றும் வருவாய் ஆய்வாளர் (RI) மூலம் பரிசீலிக்கப்படும்.
# 5. **பேன்ஷன் வழங்கல்** – அனுமதி கிடைத்தவுடன், மாதாந்திரமாக உங்கள் வங்கி கணக்கில் விதவை பेंஷன் தொகை வரவழைக்கப்படும்.

# %% [markdown]
# <span style="color: red; font-size: 20px;">PHASE 10 — Gradio User Interface (Chatbot)</span>

# %%
import gradio as gr

def chat_fn(message, history):
    return tn_answer(message)

ui = gr.ChatInterface(
    chat_fn,
    title="TN Vazikatti AI (TN Government Assistant)",
    description="Ask anything about TN Government Schemes. Answers in English + Tamil."
)

ui.launch()
# Out:
# C:\Anaconda\envs\aiml\Lib\site-packages\gradio\chat_interface.py:347: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
